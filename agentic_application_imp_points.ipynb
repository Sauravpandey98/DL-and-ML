# %%
import openai

# %%
prompt = """In a world where technology and humanity intersect, artificial intelligence has become an integral part of our daily lives. From smart assistants that help us navigate our schedules to complex algorithms that power autonomous vehicles, the evolution of AI continues to reshape our society in profound ways. Consider the ethical implications of developing increasingly sophisticated AI systems: How do we ensure they align with human values? What safeguards should we implement to prevent misuse? How do we balance innovation with responsibility?

The field of machine learning, a subset of AI, has witnessed remarkable breakthroughs in recent years. Deep learning models can now process and analyze vast amounts of data, identifying patterns and making predictions with unprecedented accuracy. Natural language processing has advanced to the point where machines can engage in meaningful conversations, translate languages in real-time, and even generate creative content. Yet, these achievements raise important questions about the future of human-AI collaboration.

As we delve deeper into the realm of artificial general intelligence (AGI), researchers grapple with fundamental questions about consciousness, intelligence, and the nature of learning itself. The concept of recursive self-improvement in AI systems presents both exciting possibilities and potential risks. How do we ensure that advanced AI systems remain beneficial to humanity while continuing to push the boundaries of what's possible?

The impact of AI extends far beyond the technological sphere, influencing economics, healthcare, education, and creative industries. In medicine, AI-powered diagnostic tools are revolutionizing patient care, while in education, adaptive learning systems are personalizing the learning experience for students worldwide. The creative sector has seen the emergence of AI-generated art, music, and literature, challenging our traditional understanding of creativity and authorship.

Security and privacy concerns surrounding AI development cannot be overlooked. As systems become more sophisticated, the potential for both beneficial and malicious applications grows. Cybersecurity experts work tirelessly to protect against AI-powered threats while leveraging AI tools to enhance defense mechanisms. The balance between data accessibility and privacy protection remains a crucial challenge in this rapidly evolving landscape.

The environmental impact of AI development and deployment deserves careful consideration. The energy consumption required for training large language models and maintaining AI infrastructure raises questions about sustainability. How can we continue advancing AI technology while minimizing our carbon footprint? What role can AI play in addressing global environmental challenges?

Looking ahead, the future of AI holds infinite possibilities. From quantum computing applications to brain-computer interfaces, emerging technologies promise to further transform our relationship with artificial intelligence. The development of emotional AI, capable of recognizing and responding to human emotions, could revolutionize human-computer interaction. Yet, these advances must be guided by ethical principles and a commitment to human welfare.

The democratization of AI technology presents both opportunities and challenges. As tools become more accessible, individuals and organizations worldwide can harness AI's potential for innovation and problem-solving. However, this accessibility also raises concerns about responsible use and the potential for misuse. How do we ensure equitable access while maintaining appropriate safeguards?

The role of regulation in AI development continues to evolve. Policymakers face the challenge of creating frameworks that promote innovation while protecting public interests. International cooperation becomes increasingly important as AI technology transcends national boundaries. The establishment of global standards and ethical guidelines remains a priority for the AI community.

As we continue to explore and expand the frontiers of artificial intelligence, the importance of interdisciplinary collaboration cannot be overstated. Computer scientists, ethicists, policymakers, and industry leaders must work together to shape the future of AI in a way that benefits all of humanity. The decisions we make today will influence the trajectory of AI development for generations to come."""

# %%
prompt1 = """Meta’s Llama 4 models - Llama 4 Scout and Llama 4 Maverick are here! These models can help people build more personalized multimodal experiences, based on large improvements in image and text understanding and instruction following, and can accommodate a range of use cases and developer needs. Whether you’re building apps for reasoning, summarization, or conversational AI, Llama 4 Scout and Maverick deliver powerful performance with open access. Llama 4 models can be run, fine-tuned and deployed in Oracle Cloud Infrastructure (OCI) Data Science. Whether you’re a data scientist or a developer, OCI offers the infrastructure and tools to move fast in the evolving world of Generative AI.

What are Llama 4's improvements?
Meta’s Llama 4 family includes:

Llama 4 Scout: A powerful multimodal model that supports context window of up to 10M tokens with 17B active parameters, 16 experts and a total of 109B parameters that can fit on a H100 (with Int4 quantization).
Llama 4 Maverick: A 17B active parameter model with 128 experts and a total of 400B parameters, delivering strong performance to cost ratio for reasoning and coding while remaining open-weight and customizable and can fit on a H100.
The new Llama 4 models use a mixture of experts (MoE) architecture. In MoE models, a single token activates only a fraction of the total parameters. MoE architectures are more compute efficient for model training and inference and, given a fixed training FLOPs budget, deliver higher quality models compared to dense architectures. Llama 4 models are designed with native multimodality, incorporating early fusion to seamlessly integrate text and vision tokens into a unified model backbone.

Llama 4 Scout and Llama 4 Maverick models are available today on Meta's website llama.com and Hugging Face, an online model repository. Oracle Cloud Infrastructure (OCI) Data Science is a platform for data scientists and developers to work with open source models powered by OCI’s compute infrastructure with features that support the entire machine learning lifecycle. You can bring in Llama 4 models from Hugging Face or Meta to use inside OCI Data Science effortlessly.

Working with Llama 4 models through the Bring-Your-Own-Container approach
OCI Data Science supports a Bring Your Own Container approach for model deployment and jobs, which enables you to deploy and fine tune the Llama 4 models.  The Bring-Your-Own-Container approach requires downloading the model from the host repository, either through the Llama website or Hugging Face, and creating a Data Science model catalog entry. Next, you would download the latest vLLM container and push it to the OCI Registry. The newly released vLLM 0.8.3 is compatible with the Llama 4 models.  Then, you can deploy the model or run a fine tuning job with the vLLM container image in the OCI Registry.  Once the model is deployed, you’re set to invoke the model with an HTTP endpoint.  For more details, please check out our tutorials Deploy LLM Models using BYOC and Batch Inferencing guide.

Llama 4 Scout is a 17 billion active parameter model with 16 experts while Llama 4 Maverick is a 17 billion active parameter model with 128 experts. Llama 4 Scout (with Int4 quantization) fits on a H100 while Llama 4 Maverick fits on a H100.  Working with a H100 in OCI Data Sciences requires a reservation for the shape.  You can do so by submitting a service request and specifying the shape and region you are interested in using the shape.  For additional information on working with GPU in OCI Data Science, please check this page.   

Coming Soon: OCI Data Science AI Quick Actions, shown in the image bellow,  is a no code solution for deploying and fine tuning LLMs.  AI Quick Actions already supports Llama 3.3 and will soon support Llama 4 models, providing a simplified process for working with these models.  """

# %%
prompt = prompt + prompt1

# %%
import openai
import os
import json
import time
from dotenv import load_dotenv

# Set your OpenRouter API key here
load_dotenv(".env", override=True)

# Create OpenAI client with proper OpenRouter configuration
client = openai.OpenAI(
    api_key=os.environ["OPENAI_API_KEY"],
)

def get_completion(prompt):
    try:
        response = client.chat.completions.create(
            model="gpt-4.1-nano",       # or any model OpenRouter makes available to you
            messages=[{"role": "system", "content": prompt}],
        )

        return response
    except Exception as e:
        print(f"Error: {e}")
        return None

# 1. Stable Prefix Cache Test
base_prefix = prompt
prompt1 = base_prefix + "What is the capital of France?"
prompt2 = f"System: {time.time()} {base_prefix}.\nWhat is the capital of France?"

# print("First (stable prefix):")
# response1 = get_completion(prompt1)  # Should have cache effect on repeated calls

# print("Second (timestamp in prefix):")
# response2 = get_completion(prompt2)  # Will not cache




# # 2. Deterministic Serialization Test
# data1 = {"a": 3, "b": 7}
# data2 = {"b": 7, "a": 3}  # Same keys, different order

# prompt1 = "System prompt:\n" + json.dumps(data1, sort_keys=True)
# prompt2 = "System prompt:\n" + json.dumps(data2, sort_keys=True)  # Use sort_keys for stable order

# print("First key order (sorted):")
# get_completion(prompt1)

# print("Second key order, but semantically identical and sorted:")
# get_completion(prompt2)

# # 3. Explicit Cache Breakpoints (conceptual, as OpenRouter API generally follows OpenAI context behavior)
# messages = [
#     {"role": "system", "content": "Stable system prompt."},
#     {"role": "user", "content": "First query."}, # No cache break here
#     {"role": "user", "content": "Second query."}
# ]
# (You can pass such a list to get_completion if you wish to test message-based cache behavior)
# Out:
# Second (timestamp in prefix):
